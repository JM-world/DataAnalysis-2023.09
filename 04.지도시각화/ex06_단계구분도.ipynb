# %% [markdown]
# ### 단계 구분도(Choropleth)
# - 서울시 구별 CCTV 인구

# %%
import json, folium
import pandas as pd

# %% [markdown]
# - 데이터 준비

# %%
df = pd.read_csv('../02.Pandas/data/서울시_구별_CCTV_인구_현황.csv', index_col='구분')
df.head()
# Out:
#      CCTV댓수  최근증가율     인구수     내국인    외국인    고령자  외국인비율  고령자비율
# 구분
# 종로구    1835  28.77  152212  141060  11152  28265   7.33  18.57
# 중구     2584  34.87  131390  120963  10427  25353   7.94  19.30
# 용산구    2970  50.81  232482  217756  14726  39478   6.33  16.98
# 성동구    4040  26.83  287240  280240   7000  48238   2.44  16.79
# 광진구    3480  34.51  350925  336801  14124  54854   4.02  15.63

# %%
geo_data = json.load(open('data/seoul_geo_simple.json', encoding='utf-8'))

# %% [markdown]
# - 단계 구분도 그리기

# %%
map = folium.Map([37.55, 126.98], zoom_start=11, tiles='Stamen Toner')
folium.Choropleth(
    geo_data=geo_data,      # GEO 지도 데이터
    data= df.CCTV댓수,      # 단계구분도로 보여줄 데이터
    columns=[df.index, df.CCTV댓수],    # 데이터 프레임에서 추출한 항목
    fill_color = 'RdPu',          # Colormap
    key_on='feature.id'     # 지도에서 조인할 항목
).add_to(map)
title_html = '<h3 align= "center" style="font-size:20px"> 구별 CCTV 설치댓수 </h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3c351506dac3b99269e4f7075cae5a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align= &quot;center&quot; style=&quot;font-size:20px&quot;&gt; 구별 CCTV 설치댓수 &lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3c351506dac3b99269e4f7075cae5a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b3c351506dac3b99269e4f7075cae5a1 = L.map(
#                 &quot;map_b3c351506dac3b99269e4f7075cae5a1&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d95a553e7f2d9ae13f5eae3dde961fc = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b3c351506dac3b99269e4f7075cae5a1);
#
#
#             var choropleth_0e5e15800c68c0f2c3f19f5cddec4787 = L.featureGroup(
#                 {}
#             ).addTo(map_b3c351506dac3b99269e4f7075cae5a1);
#
#
#         function geo_json_dfe63c74556c77bd7e7495afae620d5c_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub0a8\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7a0177&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc11c\ucd08\uad6c&quot;: case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;: case &quot;\uc740\ud3c9\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f768a1&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;: case &quot;\uc911\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feebe2&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\uc911\ub791\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fa9fb5&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fcc5c0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_dfe63c74556c77bd7e7495afae620d5c_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_dfe63c74556c77bd7e7495afae620d5c = L.geoJson(null, {
#                 onEachFeature: geo_json_dfe63c74556c77bd7e7495afae620d5c_onEachFeature,
#
#                 style: geo_json_dfe63c74556c77bd7e7495afae620d5c_styler,
#         });
#
#         function geo_json_dfe63c74556c77bd7e7495afae620d5c_add (data) {
#             geo_json_dfe63c74556c77bd7e7495afae620d5c
#                 .addData(data)
#                 .addTo(choropleth_0e5e15800c68c0f2c3f19f5cddec4787);
#         }
#             geo_json_dfe63c74556c77bd7e7495afae620d5c_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.146

# %% [markdown]
# - 자치구 이름 쓰기

# %%
import numpy as np
def get_text_location(geo_str):
    gu_dict = {}
    for gu in geo_str['features']:
        for coord in gu['geometry']['coordinates']:
            geo = np.array(coord)
            gu_dict[gu['id']] = [np.mean(geo[:,1]), np.mean(geo[:,0])]
    return gu_dict

# %%
gu_dict = get_text_location(geo_data)
gu_dict
# Out:
# {'강동구': [37.546532751824586, 127.14078218193268],
#  '송파구': [37.50620055459428, 127.11197246712628],
#  '강남구': [37.49679934694853, 127.0673229896189],
#  '서초구': [37.47066332386016, 127.0390912771612],
#  '관악구': [37.46393155080159, 126.94996289929526],
#  '동작구': [37.495988209152785, 126.9530748356924],
#  '영등포구': [37.51883998627326, 126.91028348590825],
#  '금천구': [37.46241523438773, 126.9050257773362],
#  '구로구': [37.49166908254099, 126.85870943441728],
#  '강서구': [37.55703289257873, 126.83102419541086],
#  '양천구': [37.529418412364095, 126.85252712500812],
#  '마포구': [37.5599165285085, 126.9176866353821],
#  '서대문구': [37.57597915089086, 126.94816079153975],
#  '은평구': [37.61445865754635, 126.93220977883982],
#  '노원구': [37.651705676071316, 127.07821750766884],
#  '도봉구': [37.66711228271955, 127.03387331602003],
#  '강북구': [37.646476408369075, 127.01356807286824],
#  '성북구': [37.61007782092726, 127.02020916322154],
#  '중랑구': [37.59847817045754, 127.09036092595524],
#  '동대문구': [37.57621738848033, 127.04968775012617],
#  '광진구': [37.5486403510376, 127.08823488581795],
#  '성동구': [37.551787378412435, 127.03823181737474],
#  '용산구': [37.532503472750385, 126.98787093185209],
#  '중구': [37.55684483941085, 126.99228407760529],
#  '종로구': [37.5998704500112, 126.98082827261973]}

# %%
for gu_name in df.index:
    folium.map.Marker(
        location=gu_dict[gu_name],
        icon = folium.DivIcon(icon_size=(80, 20), icon_anchor=(20, 0),
                    html=f"<span style='font-size: 10pt'>{gu_name}</span>")
    ).add_to(map)


map

# %% [markdown]
# - 구별 외국인 수

# %%
map = folium.Map([37.55, 126.98], zoom_start=11, tiles='Stamen Toner')
folium.Choropleth(
    geo_data=geo_data,     
    data= df.외국인,      
    columns=[df.index, df.외국인],    
    fill_color = 'RdPu',          
    key_on='feature.id'    
).add_to(map)
title_html = '<h3 align= "center" style="font-size:20px"> 구별 CCTV 설치댓수 </h3>'
map.get_root().html.add_child(folium.Element(title_html))
for gu_name in df.index:
    folium.map.Marker(
        location=gu_dict[gu_name],
        icon = folium.DivIcon(icon_size=(80, 20), icon_anchor=(20, 0),
                    html=f"<span style='font-size: 10pt'>{gu_name}</span>")
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_706dcb58f71ccfb4f4676f4770a01017 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align= &quot;center&quot; style=&quot;font-size:20px&quot;&gt; 구별 CCTV 설치댓수 &lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_706dcb58f71ccfb4f4676f4770a01017&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_706dcb58f71ccfb4f4676f4770a01017 = L.map(
#                 &quot;map_706dcb58f71ccfb4f4676f4770a01017&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b1456ae24ab222fe392f12cc8b7f21d = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_706dcb58f71ccfb4f4676f4770a01017);
#
#
#             var choropleth_04e265f9f3487230e4ce0314791ce1ba = L.featureGroup(
#                 {}
#             ).addTo(map_706dcb58f71ccfb4f4676f4770a01017);
#
#
#         function geo_json_3c5fe3b078cc00d3e8b0f1aabb8c9c60_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uad00\uc545\uad6c&quot;: case &quot;\uae08\ucc9c\uad6c&quot;: case &quot;\uc11c\ub300\ubb38\uad6c&quot;: case &quot;\uad11\uc9c4\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f768a1&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\uc131\ubd81\uad6c&quot;: case &quot;\uc911\uad6c&quot;: case &quot;\uc885\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fa9fb5&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc601\ub4f1\ud3ec\uad6c&quot;: case &quot;\uad6c\ub85c\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#7a0177&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\ub3d9\ub300\ubb38\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c51b8a&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc131\ub3d9\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fcc5c0&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feebe2&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_3c5fe3b078cc00d3e8b0f1aabb8c9c60_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_3c5fe3b078cc00d3e8b0f1aabb8c9c60 = L.geoJson(null, {
#                 onEachFeature: geo_json_3c5fe3b078cc00d3e8b0f1aabb8c9c60_onEachFeature,
#
#                 style: geo_json_3c5fe3b078cc00d3e8b0f1aabb8c9c60_styler,
#         });
#
#         function geo_json_3c5fe3b078cc00d3e8b0f1aabb8c9c60_add (data) {
#             geo_json_3c5fe3b078cc00d3e8b0f1aabb8c9c60
#                 .addData(data)
#                 .addTo(choropleth_04e265f9f3487230e4ce0314791ce1ba);
#         }
#             geo_json_3c5fe3b078cc00d3e8b0f1aabb8c9c60_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37

# %% [markdown]
# - 인당 CCTV 댓수

# %%
df['인당 CCTV댓수'] = (df['CCTV댓수'] / df['인구수']).round(3)
df.head()
# Out:
#      CCTV댓수  최근증가율     인구수     내국인    외국인    고령자  외국인비율  고령자비율  인당 CCTV댓수
# 구분
# 종로구    1835  28.77  152212  141060  11152  28265   7.33  18.57      0.012
# 중구     2584  34.87  131390  120963  10427  25353   7.94  19.30      0.020
# 용산구    2970  50.81  232482  217756  14726  39478   6.33  16.98      0.013
# 성동구    4040  26.83  287240  280240   7000  48238   2.44  16.79      0.014
# 광진구    3480  34.51  350925  336801  14124  54854   4.02  15.63      0.010

# %%
map = folium.Map([37.55, 126.98], zoom_start=11, tiles='Stamen Toner')
folium.Choropleth(
    geo_data=geo_data,      # GEO 지도 데이터
    data= df['인당 CCTV댓수'],      # 단계구분도로 보여줄 데이터
    columns=[df.index, df['인당 CCTV댓수']],    # 데이터 프레임에서 추출한 항목
    color = '',          # Colormap
    key_on='feature.id'     # 지도에서 조인할 항목
).add_to(map)
title_html = '<h3 align= "center" style="font-size:20px"> 구별 CCTV 설치댓수 </h3>'
map.get_root().html.add_child(folium.Element(title_html))
for gu_name in df.index:
    folium.map.Marker(
        location=gu_dict[gu_name],
        icon = folium.DivIcon(icon_size=(80, 20), icon_anchor=(20, 0),
                    html=f"<span style='font-size: 10pt'>{gu_name}</span>")
    ).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e809f562c0fcc27d4abb01bec833aaf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align= &quot;center&quot; style=&quot;font-size:20px&quot;&gt; 구별 CCTV 설치댓수 &lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e809f562c0fcc27d4abb01bec833aaf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6e809f562c0fcc27d4abb01bec833aaf = L.map(
#                 &quot;map_6e809f562c0fcc27d4abb01bec833aaf&quot;,
#                 {
#                     center: [37.55, 126.98],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ccd73c8322983ac575488536832f08bd = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6e809f562c0fcc27d4abb01bec833aaf);
#
#
#             var choropleth_cf35b91191111208f9a3caa31e0656e1 = L.featureGroup(
#                 {}
#             ).addTo(map_6e809f562c0fcc27d4abb01bec833aaf);
#
#
#         function geo_json_7a1a5ea8d29de9692bc49e6e1ea618c7_styler(feature) {
#             switch(feature.id) {
#                 case &quot;\uac15\ub3d9\uad6c&quot;: case &quot;\uc1a1\ud30c\uad6c&quot;: case &quot;\ub3d9\uc791\uad6c&quot;: case &quot;\uac15\uc11c\uad6c&quot;: case &quot;\ub9c8\ud3ec\uad6c&quot;: case &quot;\ub178\uc6d0\uad6c&quot;: case &quot;\ub3c4\ubd09\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#eff3ff&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uac15\ub0a8\uad6c&quot;: case &quot;\uc131\ub3d9\uad6c&quot;: case &quot;\uc6a9\uc0b0\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#6baed6&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc591\ucc9c\uad6c&quot;: case &quot;\ub3d9\ub300\ubb38\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#c6dbef&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 case &quot;\uc911\uad6c&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#08519c&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#9ecae1&quot;, &quot;fillOpacity&quot;: 0.6, &quot;opacity&quot;: 1, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_7a1a5ea8d29de9692bc49e6e1ea618c7_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7a1a5ea8d29de9692bc49e6e1ea618c7 = L.geoJson(null, {
#                 onEachFeature: geo_json_7a1a5ea8d29de9692bc49e6e1ea618c7_onEachFeature,
#
#                 style: geo_json_7a1a5ea8d29de9692bc49e6e1ea618c7_styler,
#         });
#
#         function geo_json_7a1a5ea8d29de9692bc49e6e1ea618c7_add (data) {
#             geo_json_7a1a5ea8d29de9692bc49e6e1ea618c7
#                 .addData(data)
#                 .addTo(choropleth_cf35b91191111208f9a3caa31e0656e1);
#         }
#             geo_json_7a1a5ea8d29de9692bc49e6e1ea618c7_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.16683184366129, 37.57672487388627], [127.18408792330152, 37.55814280369575], [127.16530984307447, 37.54221851258693], [127.14672806823502, 37.51415680680291], [127.12123165719615, 37.52528270089], [127.1116764203608, 37.540669955324965], [127.11519584981606, 37.557533180704915]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;properties&quot;: {&quot;base_year&quot;: &quot;2013&quot;, &quot;code&quot;: &quot;11250&quot;, &quot;name&quot;: &quot;\uac15\ub3d9\uad6c&quot;, &quot;name_eng&quot;: &quot;Gangdong-gu&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.0690698130372, 37.522279423505026], [127.10087519791962, 37.524841220167055], [127.1116764203608, 37.540669955324965], [127.12123165719615, 37.52528270089], [127.14672806823502, 37.51415680680291], [127.1634944215765, 37.497445406097484], [127.14206058413274, 37.47089819098501], [127.12440571080893, 37.462404455
