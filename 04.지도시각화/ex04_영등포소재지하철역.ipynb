# %% [markdown]
# - 영등포구 소재 지하철역

# %%
import folium
import pandas as pd

# %%
df = pd.read_csv('data/영등포소재 지하철역2.csv')
df
# Out:
#        이름                             주소         위도          경도
# 0    영등포역  서울특별시 영등포구 경인로 지하843 (영등포동3가)  37.516463  126.906659
# 1    신도림역       서울특별시 구로구 경인로 625 (신도림동)  37.507084  126.884719
# 2     당산역     서울특별시 영등포구 당산로 229 (당산동6가)  37.534957  126.902731
# 3    여의도역   서울특별시 영등포구 여의나루로 지하40 (여의도동)  37.521842  126.924485
# 4  영등포구청역   서울특별시 영등포구 당산로 지하121 (당산동3가)  37.525700  126.896627

# %%
map = folium.Map(location=[df['위도'].mean(), df['경도'].mean()], zoom_start=14)    # Center position
for i in df.index:
    folium.Marker(
        location=[df['위도'][i],df['경도'][i]],
        tooltip=df['이름'][i],
        popup=folium.Popup(df['주소'][i], max_width=200)
    ).add_to(map)
title_html = '<h3 align= "center" style="font-size:20px"> 영등포소재 주요 지하철역</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1843b8c7f558d05d5e519b28a969987d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align= &quot;center&quot; style=&quot;font-size:20px&quot;&gt; 영등포소재 주요 지하철역&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1843b8c7f558d05d5e519b28a969987d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1843b8c7f558d05d5e519b28a969987d = L.map(
#                 &quot;map_1843b8c7f558d05d5e519b28a969987d&quot;,
#                 {
#                     center: [37.52120913312664, 126.9030439466804],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c31d9e50e5de805d0b5bde56ffa22504 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1843b8c7f558d05d5e519b28a969987d);
#
#
#             var marker_878a4ad21352fea64649b752701057dc = L.marker(
#                 [37.5164625580995, 126.906658750671],
#                 {}
#             ).addTo(map_1843b8c7f558d05d5e519b28a969987d);
#
#
#         var popup_5da3d8f2b227abb52ec96764c657a52a = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_72fc6bc99ec29f79885dee00ee043316 = $(`&lt;div id=&quot;html_72fc6bc99ec29f79885dee00ee043316&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 경인로 지하843 (영등포동3가)&lt;/div&gt;`)[0];
#                 popup_5da3d8f2b227abb52ec96764c657a52a.setContent(html_72fc6bc99ec29f79885dee00ee043316);
#
#
#
#         marker_878a4ad21352fea64649b752701057dc.bindPopup(popup_5da3d8f2b227abb52ec96764c657a52a)
#         ;
#
#
#
#
#             marker_878a4ad21352fea64649b752701057dc.bindTooltip(
#                 `&lt;div&gt;
#                      영등포역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cf8543274b3c77af7140de01d54acbdc = L.marker(
#                 [37.5070842748567, 126.884718686628],
#                 {}
#             ).addTo(map_1843b8c7f558d05d5e519b28a969987d);
#
#
#         var popup_5df7fa90e295539f85f12fe1fccd1328 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_10d0280a67019a97275d9e9859e29acc = $(`&lt;div id=&quot;html_10d0280a67019a97275d9e9859e29acc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 구로구 경인로 625 (신도림동)&lt;/div&gt;`)[0];
#                 popup_5df7fa90e295539f85f12fe1fccd1328.setContent(html_10d0280a67019a97275d9e9859e29acc);
#
#
#
#         marker_cf8543274b3c77af7140de01d54acbdc.bindPopup(popup_5df7fa90e295539f85f12fe1fccd1328)
#         ;
#
#
#
#
#             marker_cf8543274b3c77af7140de01d54acbdc.bindTooltip(
#                 `&lt;div&gt;
#                      신도림역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c5bdfd65a8860c6c1d560855a6b47871 = L.marker(
#                 [37.534956866618, 126.90273071003],
#                 {}
#             ).addTo(map_1843b8c7f558d05d5e519b28a969987d);
#
#
#         var popup_a852fff2b77ffe5ca72b1ed34f42eb1d = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_eaefc11a99d60c4f3dc6c519397d726b = $(`&lt;div id=&quot;html_eaefc11a99d60c4f3dc6c519397d726b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 당산로 229 (당산동6가)&lt;/div&gt;`)[0];
#                 popup_a852fff2b77ffe5ca72b1ed34f42eb1d.setContent(html_eaefc11a99d60c4f3dc6c519397d726b);
#
#
#
#         marker_c5bdfd65a8860c6c1d560855a6b47871.bindPopup(popup_a852fff2b77ffe5ca72b1ed34f42eb1d)
#         ;
#
#
#
#
#             marker_c5bdfd65a8860c6c1d560855a6b47871.bindTooltip(
#                 `&lt;div&gt;
#                      당산역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4612e6f11ebcb7aaf2da2157b45151f8 = L.marker(
#                 [37.5218423045786, 126.924484687694],
#                 {}
#             ).addTo(map_1843b8c7f558d05d5e519b28a969987d);
#
#
#         var popup_901385e342223a16c4f5a12c95b625aa = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_ae54e71a28ae5b029c8bdf742c27a103 = $(`&lt;div id=&quot;html_ae54e71a28ae5b029c8bdf742c27a103&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 여의나루로 지하40 (여의도동)&lt;/div&gt;`)[0];
#                 popup_901385e342223a16c4f5a12c95b625aa.setContent(html_ae54e71a28ae5b029c8bdf742c27a103);
#
#
#
#         marker_4612e6f11ebcb7aaf2da2157b45151f8.bindPopup(popup_901385e342223a16c4f5a12c95b625aa)
#         ;
#
#
#
#
#             marker_4612e6f11ebcb7aaf2da2157b45151f8.bindTooltip(

# %%
df['color'] = ['red', 'blue', 'green', 'violet', 'orange']
df
# Out:
#        이름                             주소         위도          경도   color
# 0    영등포역  서울특별시 영등포구 경인로 지하843 (영등포동3가)  37.516463  126.906659     red
# 1    신도림역       서울특별시 구로구 경인로 625 (신도림동)  37.507084  126.884719    blue
# 2     당산역     서울특별시 영등포구 당산로 229 (당산동6가)  37.534957  126.902731   green
# 3    여의도역   서울특별시 영등포구 여의나루로 지하40 (여의도동)  37.521842  126.924485  violet
# 4  영등포구청역   서울특별시 영등포구 당산로 지하121 (당산동3가)  37.525700  126.896627  orange

# %%
map = folium.Map(location=[df['위도'].mean(), df['경도'].mean()], zoom_start=14)    # Center position
for i in df.index:
    folium.Circle(
        location=[df['위도'][i],df['경도'][i]],
        tooltip=df['이름'][i],
        radius=100, color = df['color'][i], fill=True,
        popup=folium.Popup(df['주소'][i], max_width=200)
    ).add_to(map)
    folium.map.Marker(
        location=[df['위도'][i],df['경도'][i]],
        icon = folium.DivIcon(icon_size=(80,20), icon_anchor=(20,0),
            html=f'<span style="fontsize: 10pt">{df["이름"][i]}</span>')
    ).add_to(map)

folium.Marker(
    location=[df['위도'].mean(), df['경도'].mean()],
    icon = folium.CustomIcon('data/pushpin.png'), icon_size=(30,30)
)

title_html = '<h3 align= "center" style="font-size:20px"> 영등포소재 주요 지하철역</h3>'
map.get_root().html.add_child(folium.Element(title_html))
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_761139dcf8bd630934003c8de35d31d7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;h3 align= &quot;center&quot; style=&quot;font-size:20px&quot;&gt; 영등포소재 주요 지하철역&lt;/h3&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_761139dcf8bd630934003c8de35d31d7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_761139dcf8bd630934003c8de35d31d7 = L.map(
#                 &quot;map_761139dcf8bd630934003c8de35d31d7&quot;,
#                 {
#                     center: [37.52120913312664, 126.9030439466804],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c7cabdcde801f2c8178aa5d1621f27e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_761139dcf8bd630934003c8de35d31d7);
#
#
#             var circle_62bc54ac8c4c3db8d7b415471af19927 = L.circle(
#                 [37.5164625580995, 126.906658750671],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_761139dcf8bd630934003c8de35d31d7);
#
#
#         var popup_ff5a196325da588b056ecfb0a6f61ea6 = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_7710219ab7074a20eb161593970dac0a = $(`&lt;div id=&quot;html_7710219ab7074a20eb161593970dac0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 영등포구 경인로 지하843 (영등포동3가)&lt;/div&gt;`)[0];
#                 popup_ff5a196325da588b056ecfb0a6f61ea6.setContent(html_7710219ab7074a20eb161593970dac0a);
#
#
#
#         circle_62bc54ac8c4c3db8d7b415471af19927.bindPopup(popup_ff5a196325da588b056ecfb0a6f61ea6)
#         ;
#
#
#
#
#             circle_62bc54ac8c4c3db8d7b415471af19927.bindTooltip(
#                 `&lt;div&gt;
#                      영등포역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_648e70e5c8b8447be6041e2f3b587a17 = L.marker(
#                 [37.5164625580995, 126.906658750671],
#                 {}
#             ).addTo(map_761139dcf8bd630934003c8de35d31d7);
#
#
#             var div_icon_20d69f6008c92c8b1b6c31d69b4d9d61 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan style=\&quot;fontsize: 10pt\&quot;\u003e\uc601\ub4f1\ud3ec\uc5ed\u003c/span\u003e&quot;, &quot;iconAnchor&quot;: [20, 0], &quot;iconSize&quot;: [80, 20]});
#             marker_648e70e5c8b8447be6041e2f3b587a17.setIcon(div_icon_20d69f6008c92c8b1b6c31d69b4d9d61);
#
#
#             var circle_8e04d6c606c13bf63de0ceda769821ae = L.circle(
#                 [37.5070842748567, 126.884718686628],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_761139dcf8bd630934003c8de35d31d7);
#
#
#         var popup_78f00cdb5916a288a41892604735ca9c = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_201512f0718b5873e684deb2e31fb04f = $(`&lt;div id=&quot;html_201512f0718b5873e684deb2e31fb04f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;서울특별시 구로구 경인로 625 (신도림동)&lt;/div&gt;`)[0];
#                 popup_78f00cdb5916a288a41892604735ca9c.setContent(html_201512f0718b5873e684deb2e31fb04f);
#
#
#
#         circle_8e04d6c606c13bf63de0ceda769821ae.bindPopup(popup_78f00cdb5916a288a41892604735ca9c)
#         ;
#
#
#
#
#             circle_8e04d6c606c13bf63de0ceda769821ae.bindTooltip(
#                 `&lt;div&gt;
#                      신도림역
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4c4eb38678c4451a12805440294fc586 = L.marker(
#                 [37.5070842748567, 126.884718686628],
#                 {}
#             ).addTo(map_761139dcf8bd630934003c8de35d31d7);
#
#
#             var div_icon_a270ffbbd6edd3989966f854a923cb60 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cspan style=\&
