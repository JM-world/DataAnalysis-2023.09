# %%
num1 = "..."
num2 = "..."

# %%
temp = ""
if len(num1) > len(num2):
    temp = num1[:]
    num1 = num2[:]
    num2 = temp
len_num1 = len(num1)
num1, num2, temp
# Out:
# ('...',
#  '...',
#  '')

# %%
num3 = num2[-len_num1:]
num3
# Out:
# '...'

# %%
num_list = []

# %%
for i in num2[:-len_num1]:
    num_list.append(i)
num_list = list(map(int, num_list))
num_list.append(num3)
num_list
# Out:
# ['...']

# %%
num_list[-1] = num_list[-1] + int(num1)

# %%
num_list
# Out:
# [5, 102]

# %%
win_num = num_list[-1] // 10 ** len_num1
win_num
# Out:
# 1

# %%
str(num_list[-1])[:1]
# Out:
# '1'

# %%
win_num = num_list[-1] // 10 ** len_num1
if len(str(num_list[-1])) > len_num1:
    num_list[-1] = str(num_list[-1])[1:]
    print(num_list)
else:
    print(''.join(list(map(str,num_list))))
# Out:
# [5, '02']

# %%
for k in range(len(num_list)-2, -1, -1):
    num_list[k] = num_list[k] + win_num
    if num_list[k] >= 10 and k != 0:
        num_list[k] = num_list[k] - 10
        win_num = 1
    else:
        print(''.join(list(map(str,num_list))))
print(''.join(list(map(str, num_list))))
# Out:
# 602
# 602
